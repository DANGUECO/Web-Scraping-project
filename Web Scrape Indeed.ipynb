# %%
import csv
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd


def get_url(position, location):
    """Generate url from position and location"""
    # remember to replace so it results q= {] and l={}
    placeholder = 'https://nz.indeed.com/jobs?q={}&l={}'
    # Format correctly to use url for multiple jobs.
    url = placeholder.format(position, location)
    return url


# create a function for grabbing all the necessary information
def information(card):
    # fast way to get the title.
    title = card.h2.a.get('title')
    job_url = 'https://nz.indeed.com' + card.h2.a.get('href')
    location = card.find('div', 'recJobLoc').get('data-rc-loc')
    summary = card.find('div', 'summary').text.strip()
    postdate = card.find('span', 'date').text.strip()
    currentTime = datetime.today().strftime('%Y-%m-%d')

    # need to account for none type as some information maybe missing.
    try:
        company = card.find('span', 'company').text.strip()
    except AttributeError:
        company = ''

    try:
        salary = card.find('span', 'salaryText').text.strip()
    except AttributeError:
        salary = ''

    record = (title, company, location, summary, postdate, currentTime, salary, job_url)
    return record


# NOTE:the code below is mainly used from Israels github at https://github.com/israel-dryer/Indeed-Job-Scraper

def main(position, location):
    """Run the main program routine"""
    records = []
    url = get_url(position, location)

    # extract the job data
    while True:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        cards = soup.find_all('div', 'jobsearch-SerpJobCard')
        for card in cards:
            record = information(card)
            records.append(record)
        # keeps trying to find more pages until there is an error. If there is an error then there are no more pages.
        try:
            url = 'https://nz.indeed.com' + soup.find('a', {'aria-label': 'Next'}).get('href')
        except AttributeError:
            break

    # save the job data
    with open('dataAnalystJobPosting.csv', 'w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        # Creates a header Row
        writer.writerow(
            ['JobTitle', 'Company', 'Location', 'Summary', 'ExtractDate', 'Current Date', 'Salary', 'JobUrl'])
        # Adds the record and other information under the header.
        writer.writerows(records)


#  run the main program
# main(position and location here for swapping)
main('data analyst', 'wellington')

# %%
job = pd.read_csv('dataAnalystJobPosting.csv')
job
# Out:
#                                              JobTitle  \
# 0                                        Data Analyst
# 1                                    Research Analyst
# 2                                     Systems Analyst
# 3                                 Senior Data Analyst
# 4                           Epidemiologists x 3 - ESR
# 5                             Senior Business Analyst
# 6                                  Financial Modeller
# 7                         Risk and Compliance Analyst
# 8                                    Business Analyst
# 9                              Analysis - Team Leader
# 10                         Analyst, Sample Management
# 11                 Data Analyst / Senior Data Analyst
# 12                              Pae Arahi o Te Tiratu
# 13                   Technical Implementation Analyst
# 14                                   Business Analyst
# 15                                Senior Test Analyst
# 16                Analyst/Senior Analyst - Fixed Term
# 17                                    Data Specialist
# 18     Senior Business Analyst, Investment Programmes
# 19                                Senior Data Analyst
# 20                        Linux Systems Administrator
# 21                            Senior Business Analyst
# 22                            Senior Business Analyst
# 23                             Senior Systems Analyst
# 24                                    Systems Manager
# 25                                   Business Analyst
# 26                   Senior Project Reporting Analyst
# 27                       Business Development Manager
# 28                 Service Desk Analyst - Interactive
# 29                                   Business Analyst
# 30                         Senior Security Specialist
# 31                         Business Portfolio Analyst
# 32          Financial Analyst / Management Accountant
# 33                             QA Tester - Fixed Term
# 34            Senior Workforce Development Strategist
# 35                   Integration Analyst - Fixed Term
# 36  Configuration Analyst - Local Government - Fix...
# 37                Business Analyst - Local Government
# 38                         Technical Business Analyst
# 39                                            Manager
# 40            Configurator Managed Forms - Fixed Term
# 41                Enterprise/Senior Business Analysts
# 42  Software Developer - Local Government - Fixed ...
# 43                                   Business Analyst
# 44  Senior Business Analyst - Local Government Sol...
#
#                                Company                        Location  \
# 0                                BCITO     Wellington City, Wellington
# 1                          PublicVoice          Lower Hutt, Wellington
# 2                                BCITO     Wellington City, Wellington
# 3                       H2R Consulting     Wellington City, Wellington
# 4                                  ESR             Porirua, Wellington
# 5                                  BNZ     Wellington City, Wellington
# 6                             Deloitte     Wellington City, Wellington
# 7                                Cigna             Mount Victoria 6011
# 8                   Beyond Recruitment     Wellington City, Wellington
# 9                              PHARMAC  Wellington Central, Wellington
# 10  NZ Ministry for Primary Industries     Wellington City, Wellington
# 11                      H2R Consulting     Wellington City, Wellington
# 12     New Zealand Ministry of Justice     Wellington City, Wellington
# 13                          Juvare LLC             Mount Victoria 6011
# 14                            Twoticks     Wellington City, Wellington
# 15                        The Treasury     Wellington City, Wellington
# 16                             PHARMAC  Wellington Central, Wellington
# 17                                HAYS     Wellington City, Wellington
# 18  NZ Ministry for Primary Industries     Wellington City, Wellington
# 19                      Robert Walters     Wellington City, Wellington
# 20                         NZ Gov MBIE     Wellington City, Wellington
# 21                      H2R Consulting     Wellington City, Wellington
# 22                             Qual IT     Wellington City, Wellington
# 23                           Objective     Wellington City, Wellington
# 24   Department of Internal Affairs NZ     Wellington City, Wellington
# 25                              Hudson  Wellington Central, Wellington
# 26             Jacksonstone & Partners     Wellington City, Wellington
# 27                                 AIA     Wellington City, Wellington
# 28                             Datacom     Wellington City, Wellington
# 29                            Twoticks     Wellington City, Wellington
# 30                                 BNZ     Wellington City, Wellington
# 31                      Robert Walters            Wellington City 6011
# 32             Jacksonstone & Partners     Wellington City, Wellington
# 33                             Datacom     Wellington City, Wellington
# 34                               BCITO     Wellington City, Wellington
# 35                             Datacom     Wellington City, Wellington
# 36                             Datacom     Wellington City, Wellington
# 37                             Datacom     Wellington City, Wellington
# 38                             Datacom     Wellington City, Wellington
# 39                      H2R Consulting     Wellington City, Wellington
# 40                             Datacom     Wellington City, Wellington
# 41                              Hudson  Wellington Central, Wellington
# 42                             Datacom     Wellington City, Wellington
# 43                            Twoticks     Wellington City, Wellington
# 44                             Datacom     Wellington City, Wellington
#
#                                               Summary   ExtractDate  \
# 0   The key purpose of this role is to turn data i...   17 days ago
# 1   The role requires analysis of both qualitative...   17 days ago
# 2   You have a passion to work with technology and...   18 days ago
# 3   On the reverse, the ability to translate this ...  30+ days ago
# 4   Are you an epidemiologist or a epidemiology an...  30+ days ago
# 5   Use your exceptional research, data analysis a...  30+ days ago
# 6   Developing high quality financial analysis, pr...  30+ days ago
# 7   One day you may be identifying external and in...   12 days ago
# 8   Demonstrable project experience including syst...   10 days ago
# 9   Provide internal and external stakeholders wit...  30+ days ago
# 10  Receipt and analysis of test results in accord...   11 days ago
# 11  Have a passion for data analysis, forecasting ...   13 days ago
# 12  Ensuring system business practices and solutio...   16 days ago
# 13  Good understanding of servers and data flow.\n...  30+ days ago
# 14  Identify and analyse data to develop a good un...  30+ days ago
# 15  Advanced technical testing experience includin...    6 days ago
# 16  Excellent data analysis, forecasting and scena...   23 days ago
# 17  We are looking for a data specialist, a data c...  30+ days ago
# 18  To deliver and own the data governance framewo...    6 days ago
# 19  Plan, develop, deliver and support one-off dat...  30+ days ago
# 20  The security of our network and data is of par...    8 days ago
# 21  Conducting data analysis, reviewing data sets ...  30+ days ago
# 22  At least 5+ years’ experience working as a bus...   11 days ago
# 23  Analysing customer data and defining data conv...   17 days ago
# 24  Lead and manage a team comprising systems anal...   13 days ago
# 25  Experience as a business analyst working on bu...   19 days ago
# 26  To be considered we are looking for candidates...    6 days ago
# 27  Manage adviser complaints and risk, taking int...    9 days ago
# 28  We have extensive expertise in operating data ...  30+ days ago
# 29  Identify and analyse data to develop a good un...  30+ days ago
# 30  Responding to information loss alerts and inve...    6 days ago
# 31  This person will be responsible for the assess...    5 days ago
# 32  You will also have strong excel skills, and th...    5 days ago
# 33  Ability to troubleshoot issues to understand w...   17 days ago
# 34  You will have excellent experience in workforc...   13 days ago
# 35  We have extensive expertise in operating data ...  30+ days ago
# 36  We have extensive expertise in operating data ...   17 days ago
# 37  We have extensive expertise in operating data ...  30+ days ago
# 38  Business analyst with experience delivering en...  30+ days ago
# 39  Have a passion for data analysis, forecasting ...   18 days ago
# 40  We have extensive expertise in operating data ...   11 days ago
# 41  Love working with data, being able to interpre...   26 days ago
# 42  We have extensive expertise in operating data ...   17 days ago
# 43  Identify and analyse data to develop a good un...  30+ days ago
# 44  We have extensive expertise in operating data ...    9 days ago
#
#    Current Date             Salary  \
# 0    2020-12-28                NaN
# 1    2020-12-28  $30 - $70 an hour
# 2    2020-12-28                NaN
# 3    2020-12-28                NaN
# 4    2020-12-28                NaN
# 5    2020-12-28                NaN
# 6    2020-12-28                NaN
# 7    2020-12-28                NaN
# 8    2020-12-28                NaN
# 9    2020-12-28                NaN
# 10   2020-12-28                NaN
# 11   2020-12-28                NaN
# 12   2020-12-28                NaN
# 13   2020-12-28                NaN
# 14   2020-12-28                NaN
# 15   2020-12-28                NaN
# 16   2020-12-28                NaN
# 17   2020-12-28                NaN
# 18   2020-12-28                NaN
# 19   2020-12-28                NaN
# 20   2020-12-28                NaN
# 21   2020-12-28                NaN
# 22   2020-12-28                NaN
# 23   2020-12-28                NaN
# 24   2020-12-28                NaN
# 25   2020-12-28                NaN
# 26   2020-12-28                NaN
# 27   2020-12-28                NaN
# 28   2020-12-28                NaN
# 29   2020-12-28                NaN
# 30   2020-12-28                NaN
# 31   2020-12-28                NaN
# 32   2020-12-28                NaN
# 33   2020-12-28                NaN
# 34   2020-12-28                NaN
# 35   2020-12-28                NaN
# 36   2020-12-28                NaN
# 37   2020-12-28                NaN
# 38   2020-12-28                NaN
# 39   2020-12-28                NaN
# 40   2020-12-28                NaN
# 41   2020-12-28                NaN
# 42   2020-12-28                NaN
# 43   2020-12-28                NaN
# 44   2020-12-28                NaN
#
